# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
from operator import itemgetter
from CFModel import CFModel
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): CUDA is installed, but device gpu is not available  (error: Unable to get the number of gpus available: no CUDA-capable device is detected)

# %% [markdown]
# ## Define constants

# %%
TEST_CSV_FILE = 'fb15k_test.csv'
CVSC_ENTITIES_CSV_FILE = 'fb15k_cvsc_entities.csv'
CVSC_PAIRS_CSV_FILE = 'fb15k_cvsc_pairs.csv'
MODEL_WEIGHTS_FILE = 'fb15k_cvsc_weights.h5'
K_FACTORS = 50

# %% [markdown]
# ## Load FB215-237 data

# %%
triples = pd.read_csv(TEST_CSV_FILE, 
                      sep='\t', 
                      usecols=['subj', 'rel', 'obj', 'pid', 'rid'])
entities = pd.read_csv(CVSC_ENTITIES_CSV_FILE, sep='\t', usecols=['entity'])['entity'].values[1:]
entity_pairs = pd.read_csv(CVSC_PAIRS_CSV_FILE, 
                           sep='\t', 
                           usecols=['subj', 'obj', 'pid'])

# %% [markdown]
# ## Print basic dataset statistics

# %%
n_pairs = triples['pid'].max() + 1
m_relations = triples['rid'].max() + 1
l_entities = len(entities)
print n_pairs, 'pairs,', m_relations, 'relations,', l_entities, 'entities'
# Out:
# 283868 pairs, 237 relations, 14281 entities

# %% [markdown]
# ## Load model weights into evaluation model

# %%
model = CFModel(n_pairs, m_relations, K_FACTORS)
model.load_weights(MODEL_WEIGHTS_FILE)

# %% [markdown]
# ## Execute evaluation protocol
#
# From [[2]](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/main_cvsc2015.pdf):
#
# > Given a set of triples in a set disjoint from a training
# > knowledge graph, we test models on predicting the subject or
# > object of each triple, given the relation type and the other
# > argument. We rank all entities in the training knowledge base in
# > order of their likelihood of filling the argument position. We
# > report the mean reciprocal rank of the correct entity, as well as
# > HITS@10 – the percent of test triples for which the correct
# > argument was ranked in the top ten. We use filtered measures
# > following the protocol proposed in Bordes et al. (2013) – that
# > is, when we rank entities for a given position, we remove all
# > other entities that are known to be part of an existing triple in
# > the training, development, or test set. This avoids penalizing
# > the model for ranking other correct fillers higher than the
# > tested argument. We thus report filtered mean reciprocal
# > rank (labeled MRR in the Figures), and filtered HITS@10. In the
# > figures we present MRR values scaled by 100, so that the maximum
# > possible MRR is 100.

# %% [markdown]
# ** *Note: filtering not yet implemented, code neither complete nor debugged for non-filtering case anyways* **

# %%
def sp_query_reciprocal_rank(model, subj, rid, obj, entities):
    objs = [ result[0] for result in sp_query_results(model, subj, rid, entities) ]
    return reciprocal_rank(obj, objs)

def sp_query_hits_at_10(model, subj, rid, obj, entities):
    objs = [ result[0] for result in sp_query_results(model, subj, rid, entities) ]
    if obj in objs[:10]:
        return 1.0
    else:
        return 0.0

def sp_query_results(model, subj, rid, entities):
    return sorted([ [ subj, model.rank(pid, rid) ] for pid in sp_query_pairs(subj, entities) ], 
                  reverse=True, 
                  key=itemgetter(1))

def sp_query_pairs(subj, entities):
    return [ pair_id(subj, obj) for obj in entities if pair_id(subj, obj) > -1 ]

def po_query_reciprocal_rank(model, subj, rid, obj, entities):
    subjs = [ result[0] for result in po_query_results(model, obj, rid, entities) ]
    return reciprocal_rank(subj, subjs)

def po_query_hits_at_10(model, subj, rid, obj, entities):
    subjs = [ result[0] for result in po_query_results(model, obj, rid, entities) ]
    if subj in subjs[:10]:
        return 1.0
    else:
        return 0.0

def po_query_results(model, obj, rid, entities):
    return sorted([ [ obj, model.rank(pid, rid) ] for pid in sp_query_pairs(subj, entities) ], 
                  reverse=True, 
                  key=itemgetter(1))

def po_query_pairs(obj, entities):
    return [ pair_id(subj, obj) for subj in entities if pair_id(subj, obj) > -1]

def pair_id(subj, obj):
    pair = entity_pairs[(entity_pairs['subj'] == subj) & (entity_pairs['obj'] == obj)]
    if len(pair) > 0:
        return pair['pid'].values[0]
    else:
        return -1

def reciprocal_rank(correct_response, responses):
    return 1. / np.float(np.where(responses == correct_response)[0][0])

# %%
pairs = entity_pairs.to_dict(orient='records')
subj_idx = {}
obj_idx = {}
for pair in pairs:
    subj = pair['subj']
    obj = pair['obj']
    pid = pair['pid']
    if subj not in subj_idx.keys():
        subj_idx[subj] = {}
    if obj not in obj_idx.keys():
        obj_idx[obj] = {}
    subj_idx[subj][obj] = pid
    obj_idx[obj][subj] = pid

# %%
tuples = triples.to_dict(orient='records')
tuples
# Out:
# [{'obj': '/m/05lf_',
#   'pid': 263691,
#   'rel': '/travel/travel_destination/climate./travel/travel_destination_monthly_climate/month',
#   'rid': 148,
#   'subj': '/m/08966'},
#  {'obj': '/m/01q99h',
#   'pid': 263692,
#   'rel': '/music/performance_role/regular_performances./music/group_membership/group',
#   'rid': 92,
#   'subj': '/m/01hww_'},
#  {'obj': '/m/0f8l9c',
#   'pid': 263693,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/09v3jyg'},
#  {'obj': '/m/013t85',
#   'pid': 263694,
#   'rel': '/location/location/contains',
#   'rid': 15,
#   'subj': '/m/02jx1'},
#  {'obj': '/m/0m0bj',
#   'pid': 263695,
#   'rel': '/location/location/contains',
#   'rid': 15,
#   'subj': '/m/02jx1'},
#  {'obj': '/m/04ghz4m',
#   'pid': 263696,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/02bfmn'},
#  {'obj': '/m/04y9mm8',
#   'pid': 263697,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/05zrvfd'},
#  {'obj': '/m/04j53',
#   'pid': 263698,
#   'rel': '/government/government_office_category/officeholders./government/government_position_held/jurisdiction_of_office',
#   'rid': 37,
#   'subj': '/m/060bp'},
#  {'obj': '/m/082gq',
#   'pid': 263699,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/07l450'},
#  {'obj': '/m/029q3k',
#   'pid': 263700,
#   'rel': '/sports/pro_athlete/teams./sports/sports_team_roster/team',
#   'rid': 40,
#   'subj': '/m/07h1h5'},
#  {'obj': '/m/0jgd',
#   'pid': 263701,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0djb3vw'},
#  {'obj': '/m/0dxmyh',
#   'pid': 263702,
#   'rel': '/base/popstra/location/vacationers./base/popstra/vacation_choice/vacationer',
#   'rid': 122,
#   'subj': '/m/031y2'},
#  {'obj': '/m/02lq67',
#   'pid': 263703,
#   'rel': '/olympics/olympic_participating_country/medals_won./olympics/olympic_medal_honor/medal',
#   'rid': 73,
#   'subj': '/m/01d8l'},
#  {'obj': '/m/02hcv8',
#   'pid': 263704,
#   'rel': '/location/location/time_zones',
#   'rid': 154,
#   'subj': '/m/0ydpd'},
#  {'obj': '/m/02xry',
#   'pid': 263705,
#   'rel': '/people/person/places_lived./people/place_lived/location',
#   'rid': 66,
#   'subj': '/m/0738b8'},
#  {'obj': '/m/01g5v',
#   'pid': 263706,
#   'rel': '/sports/sports_team/colors',
#   'rid': 95,
#   'subj': '/m/070xg'},
#  {'obj': '/m/09nqf',
#   'pid': 263707,
#   'rel': '/location/statistical_region/rent50_2./measurement_unit/dated_money_value/currency',
#   'rid': 33,
#   'subj': '/m/0mwk9'},
#  {'obj': '/m/0sxkh',
#   'pid': 263708,
#   'rel': '/award/award_ceremony/awards_presented./award/award_honor/honored_for',
#   'rid': 103,
#   'subj': '/m/09306z'},
#  {'obj': '/m/027jk',
#   'pid': 263709,
#   'rel': '/olympics/olympic_games/participating_countries',
#   'rid': 157,
#   'subj': '/m/0kbws'},
#  {'obj': '/m/04vjh',
#   'pid': 263710,
#   'rel': '/olympics/olympic_games/participating_countries',
#   'rid': 157,
#   'subj': '/m/0kbws'},
#  {'obj': '/m/01mkq',
#   'pid': 263711,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/017j69'},
#  {'obj': '/m/0631_',
#   'pid': 263712,
#   'rel': '/location/statistical_region/religions./location/religion_percentage/religion',
#   'rid': 18,
#   'subj': '/m/07z1m'},
#  {'obj': '/m/0d060g',
#   'pid': 263713,
#   'rel': '/military/military_conflict/combatants./military/military_combatant_group/combatants',
#   'rid': 131,
#   'subj': '/m/03gqgt3'},
#  {'obj': '/m/01bx35',
#   'pid': 263714,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/01c9f2'},
#  {'obj': '/m/01s695',
#   'pid': 263715,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/01c9f2'},
#  {'obj': '/m/04n6k',
#   'pid': 263716,
#   'rel': '/user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy',
#   'rid': 118,
#   'subj': '/m/01lp8'},
#  {'obj': '/m/0121rx',
#   'pid': 263717,
#   'rel': '/influence/influence_node/influenced_by',
#   'rid': 21,
#   'subj': '/m/01xwqn'},
#  {'obj': '/m/07ssc',
#   'pid': 263718,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/065ym0c'},
#  {'obj': '/m/01_d4',
#   'pid': 263719,
#   'rel': '/people/person/place_of_birth',
#   'rid': 24,
#   'subj': '/m/06kxk2'},
#  {'obj': '/m/0lcx',
#   'pid': 263720,
#   'rel': '/people/cause_of_death/people',
#   'rid': 50,
#   'subj': '/m/08q1tg'},
#  {'obj': '/m/04399',
#   'pid': 263721,
#   'rel': '/education/educational_institution/school_type',
#   'rid': 124,
#   'subj': '/m/037fqp'},
#  {'obj': '/m/01lj9',
#   'pid': 263722,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/0xxc'},
#  {'obj': '/m/01y9jr',
#   'pid': 263723,
#   'rel': '/film/film/prequel',
#   'rid': 230,
#   'subj': '/m/01l_pn'},
#  {'obj': '/m/09gq0x5',
#   'pid': 263724,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/09sdmz'},
#  {'obj': '/m/011yn5',
#   'pid': 263725,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/09sdmz'},
#  {'obj': '/m/01d_h8',
#   'pid': 263726,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/02ghq'},
#  {'obj': '/m/0dtfn',
#   'pid': 263727,
#   'rel': '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film',
#   'rid': 32,
#   'subj': '/m/016tt2'},
#  {'obj': '/m/04zl8',
#   'pid': 263728,
#   'rel': '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film',
#   'rid': 32,
#   'subj': '/m/016tt2'},
#  {'obj': '/m/01gb54',
#   'pid': 263729,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/016tt2'},
#  {'obj': '/m/0ckd1',
#   'pid': 263730,
#   'rel': '/tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type',
#   'rid': 110,
#   'subj': '/m/07jrjb'},
#  {'obj': '/m/015fr',
#   'pid': 263731,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/09v71cj'},
#  {'obj': '/m/0dky9n',
#   'pid': 263732,
#   'rel': '/film/film/edited_by',
#   'rid': 186,
#   'subj': '/m/01k5y0'},
#  {'obj': '/m/0jm_',
#   'pid': 263733,
#   'rel': '/sports/sports_team/sport',
#   'rid': 80,
#   'subj': '/m/06x76'},
#  {'obj': '/m/0411q',
#   'pid': 263734,
#   'rel': '/people/ethnicity/people',
#   'rid': 71,
#   'subj': '/m/0x67'},
#  {'obj': '/m/030wkp',
#   'pid': 263735,
#   'rel': '/people/ethnicity/people',
#   'rid': 71,
#   'subj': '/m/0x67'},
#  {'obj': '/m/09nqf',
#   'pid': 263736,
#   'rel': '/film/film/estimated_budget./measurement_unit/dated_money_value/currency',
#   'rid': 34,
#   'subj': '/m/0gmgwnv'},
#  {'obj': '/m/09jwl',
#   'pid': 263737,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/01wkmgb'},
#  {'obj': '/m/04k4l',
#   'pid': 263738,
#   'rel': '/organization/organization_member/member_of./organization/organization_membership/organization',
#   'rid': 23,
#   'subj': '/m/0154j'},
#  {'obj': '/m/027l4q',
#   'pid': 263739,
#   'rel': '/people/deceased_person/place_of_death',
#   'rid': 39,
#   'subj': '/m/02j4sk'},
#  {'obj': '/m/0d1qmz',
#   'pid': 263740,
#   'rel': '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film',
#   'rid': 32,
#   'subj': '/m/017jv5'},
#  {'obj': '/m/04jplwp',
#   'pid': 263741,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02x2gy0'},
#  {'obj': '/m/0g_rs_',
#   'pid': 263742,
#   'rel': '/film/film/executive_produced_by',
#   'rid': 136,
#   'subj': '/m/053rxgm'},
#  {'obj': '/m/03h_yfh',
#   'pid': 263743,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/011k11'},
#  {'obj': '/m/0bdw6t',
#   'pid': 263744,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/014zfs'},
#  {'obj': '/m/0k2cb',
#   'pid': 263745,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/05typm'},
#  {'obj': '/m/06c62',
#   'pid': 263746,
#   'rel': '/film/film/featured_film_locations',
#   'rid': 106,
#   'subj': '/m/0cwy47'},
#  {'obj': '/m/09rwjly',
#   'pid': 263747,
#   'rel': '/film/film/film_festivals',
#   'rid': 191,
#   'subj': '/m/019vhk'},
#  {'obj': '/m/05zppz',
#   'pid': 263748,
#   'rel': '/people/person/gender',
#   'rid': 43,
#   'subj': '/m/06sy4c'},
#  {'obj': '/m/04f62k',
#   'pid': 263749,
#   'rel': '/tv/tv_program/regular_cast./tv/regular_tv_appearance/actor',
#   'rid': 1,
#   'subj': '/m/0dr1c2'},
#  {'obj': '/m/013m43',
#   'pid': 263750,
#   'rel': '/location/location/contains',
#   'rid': 15,
#   'subj': '/m/07b_l'},
#  {'obj': '/m/01d_h8',
#   'pid': 263751,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0mm1q'},
#  {'obj': '/m/062zjtt',
#   'pid': 263752,
#   'rel': '/film/director/film',
#   'rid': 102,
#   'subj': '/m/0prjs'},
#  {'obj': '/m/01c9dd',
#   'pid': 263753,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/01v40wd'},
#  {'obj': '/m/05dppk',
#   'pid': 256720,
#   'rel': '/award/award_winning_work/awards_won./award/award_honor/award_winner',
#   'rid': 12,
#   'subj': '/m/0kvgnq'},
#  {'obj': '/m/013b2h',
#   'pid': 263754,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/01ckbq'},
#  {'obj': '/m/07yk1xz',
#   'pid': 263755,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0f_nbyh'},
#  {'obj': '/m/02bjrlw',
#   'pid': 263756,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/0418wg'},
#  {'obj': '/m/03z19',
#   'pid': 263757,
#   'rel': '/organization/non_profit_organization/registered_with./organization/non_profit_registration/registering_agency',
#   'rid': 167,
#   'subj': '/m/02kth6'},
#  {'obj': '/m/03s6l2',
#   'pid': 263758,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/026c1'},
#  {'obj': '/m/05z96',
#   'pid': 263759,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/03j90'},
#  {'obj': '/m/02zk08',
#   'pid': 263760,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0p9sw'},
#  {'obj': '/m/0kz10',
#   'pid': 263761,
#   'rel': '/music/genre/parent_genre',
#   'rid': 52,
#   'subj': '/m/01hydr'},
#  {'obj': '/m/0vbk',
#   'pid': 263762,
#   'rel': '/government/legislative_session/members./government/government_position_held/district_represented',
#   'rid': 35,
#   'subj': '/m/01gtc0'},
#  {'obj': '/m/07ssc',
#   'pid': 263763,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0h63gl9'},
#  {'obj': '/m/0f4hc',
#   'pid': 263764,
#   'rel': '/food/food/nutrients./food/nutrition_fact/nutrient',
#   'rid': 137,
#   'subj': '/m/033cnk'},
#  {'obj': '/m/02y_3rf',
#   'pid': 263765,
#   'rel': '/food/food/nutrients./food/nutrition_fact/nutrient',
#   'rid': 137,
#   'subj': '/m/033cnk'},
#  {'obj': '/m/034qrh',
#   'pid': 263766,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/084m3'},
#  {'obj': '/m/01x5fb',
#   'pid': 263767,
#   'rel': '/education/educational_degree/people_with_this_degree./education/education/institution',
#   'rid': 89,
#   'subj': '/m/014mlp'},
#  {'obj': '/m/03sb38',
#   'pid': 263768,
#   'rel': '/film/film/production_companies',
#   'rid': 86,
#   'subj': '/m/0b7l4x'},
#  {'obj': '/m/01g63y',
#   'pid': 263769,
#   'rel': '/people/person/spouse_s./people/marriage/type_of_union',
#   'rid': 85,
#   'subj': '/m/016yvw'},
#  {'obj': '/m/016ywb',
#   'pid': 263770,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/06ltr'},
#  {'obj': '/m/03q95r',
#   'pid': 263771,
#   'rel': '/education/educational_institution/students_graduates./education/education/student',
#   'rid': 22,
#   'subj': '/m/01dq5z'},
#  {'obj': '/m/0n1h',
#   'pid': 263772,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/02vwckw'},
#  {'obj': '/m/09sb52',
#   'pid': 263773,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/049t4g'},
#  {'obj': '/m/01qncf',
#   'pid': 263774,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/08k881'},
#  {'obj': '/m/016z4k',
#   'pid': 263775,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/01w58n3'},
#  {'obj': '/m/0h0wc',
#   'pid': 263776,
#   'rel': '/award/award_ceremony/awards_presented./award/award_honor/award_winner',
#   'rid': 27,
#   'subj': '/m/0h_cssd'},
#  {'obj': '/m/0153nq',
#   'pid': 263777,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/06by7'},
#  {'obj': '/m/07ssc',
#   'pid': 263778,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/01wxdn3'},
#  {'obj': '/m/011_6p',
#   'pid': 263779,
#   'rel': '/music/artist/track_contributions./music/track_contribution/role',
#   'rid': 41,
#   'subj': '/m/01wxdn3'},
#  {'obj': '/m/014_lq',
#   'pid': 263780,
#   'rel': '/influence/influence_node/influenced_by',
#   'rid': 21,
#   'subj': '/m/03g5jw'},
#  {'obj': '/m/09bkv',
#   'pid': 263781,
#   'rel': '/organization/organization/headquarters./location/mailing_address/citytown',
#   'rid': 83,
#   'subj': '/m/02m97n'},
#  {'obj': '/m/035s37',
#   'pid': 263782,
#   'rel': '/sports/sports_league/teams./sports/sports_league_participation/team',
#   'rid': 132,
#   'subj': '/m/07y9k'},
#  {'obj': '/m/05f4p',
#   'pid': 263783,
#   'rel': '/organization/organization_founder/organizations_founded',
#   'rid': 226,
#   'subj': '/m/06c97'},
#  {'obj': '/m/02f79n',
#   'pid': 263784,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/01cwhp'},
#  {'obj': '/m/05zkcn5',
#   'pid': 263785,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/01cwhp'},
#  {'obj': '/m/02hcv8',
#   'pid': 263786,
#   'rel': '/location/location/time_zones',
#   'rid': 154,
#   'subj': '/m/02xry'},
#  {'obj': '/m/01y0s9',
#   'pid': 263787,
#   'rel': '/location/statistical_region/religions./location/religion_percentage/religion',
#   'rid': 18,
#   'subj': '/m/02xry'},
#  {'obj': '/m/08mbj5d',
#   'pid': 263788,
#   'rel': '/common/topic/webpage./common/webpage/category',
#   'rid': 25,
#   'subj': '/m/018dh3'},
#  {'obj': '/m/064lsn',
#   'pid': 263789,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/099c8n'},
#  {'obj': '/m/02h40lc',
#   'pid': 263790,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/026lgs'},
#  {'obj': '/m/03hnd',
#   'pid': 263791,
#   'rel': '/influence/influence_node/influenced_by',
#   'rid': 21,
#   'subj': '/m/03j0d'},
#  {'obj': '/m/0h7x',
#   'pid': 263792,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0ccck7'},
#  {'obj': '/m/0j2jr',
#   'pid': 263793,
#   'rel': '/sports/sports_team_location/teams',
#   'rid': 94,
#   'subj': '/m/017_cl'},
#  {'obj': '/m/04mjl',
#   'pid': 263794,
#   'rel': '/sports/pro_athlete/teams./sports/sports_team_roster/team',
#   'rid': 40,
#   'subj': '/m/0hcs3'},
#  {'obj': '/m/05xb7q',
#   'pid': 263795,
#   'rel': '/education/educational_institution/campuses',
#   'rid': 146,
#   'subj': '/m/05xb7q'},
#  {'obj': '/m/09c7w0',
#   'pid': 263796,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/063g7l'},
#  {'obj': '/m/01tz6vs',
#   'pid': 263797,
#   'rel': '/film/film/story_by',
#   'rid': 155,
#   'subj': '/m/0gy7bj4'},
#  {'obj': '/m/0ctw_b',
#   'pid': 263798,
#   'rel': '/base/biblioness/bibs_location/country',
#   'rid': 133,
#   'subj': '/m/04lc0h'},
#  {'obj': '/m/05zkcn5',
#   'pid': 263799,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/0137g1'},
#  {'obj': '/m/09nqf',
#   'pid': 263800,
#   'rel': '/education/university/domestic_tuition./measurement_unit/dated_money_value/currency',
#   'rid': 166,
#   'subj': '/m/04ycjk'},
#  {'obj': '/m/02h40lc',
#   'pid': 263801,
#   'rel': '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language',
#   'rid': 198,
#   'subj': '/m/0mgkg'},
#  {'obj': '/m/0l6mp',
#   'pid': 263802,
#   'rel': '/olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics',
#   'rid': 72,
#   'subj': '/m/01rhrd'},
#  {'obj': '/m/04gxp2',
#   'pid': 263803,
#   'rel': '/education/educational_degree/people_with_this_degree./education/education/institution',
#   'rid': 89,
#   'subj': '/m/02mjs7'},
#  {'obj': '/m/05zppz',
#   'pid': 263804,
#   'rel': '/people/person/gender',
#   'rid': 43,
#   'subj': '/m/01v90t'},
#  {'obj': '/m/07tf8',
#   'pid': 263805,
#   'rel': '/education/educational_institution/school_type',
#   'rid': 124,
#   'subj': '/m/017cy9'},
#  {'obj': '/m/09c7w0',
#   'pid': 263806,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/023kzp'},
#  {'obj': '/m/0km5c',
#   'pid': 263807,
#   'rel': '/base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed',
#   'rid': 156,
#   'subj': '/m/013yq'},
#  {'obj': '/m/07s4l',
#   'pid': 263808,
#   'rel': '/medicine/symptom/symptom_of',
#   'rid': 216,
#   'subj': '/m/02tfl8'},
#  {'obj': '/m/02ynfr',
#   'pid': 263809,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/075wx7_'},
#  {'obj': '/m/09c7w0',
#   'pid': 263810,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/055c8'},
#  {'obj': '/m/07t65',
#   'pid': 263811,
#   'rel': '/organization/organization_member/member_of./organization/organization_membership/organization',
#   'rid': 23,
#   'subj': '/m/01znc_'},
#  {'obj': '/m/01x66d',
#   'pid': 263812,
#   'rel': '/music/instrument/instrumentalists',
#   'rid': 42,
#   'subj': '/m/05148p4'},
#  {'obj': '/m/01zwy',
#   'pid': 263813,
#   'rel': '/education/educational_degree/people_with_this_degree./education/education/student',
#   'rid': 189,
#   'subj': '/m/03bwzr4'},
#  {'obj': '/m/07ssc',
#   'pid': 263814,
#   'rel': '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location',
#   'rid': 150,
#   'subj': '/m/0g5lhl7'},
#  {'obj': '/m/0h3k3f',
#   'pid': 263815,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/08qvhv'},
#  {'obj': '/m/0gqyl',
#   'pid': 263816,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/01tj34'},
#  {'obj': '/m/08mbj5d',
#   'pid': 263817,
#   'rel': '/common/topic/webpage./common/webpage/category',
#   'rid': 25,
#   'subj': '/m/012mzw'},
#  {'obj': '/m/07p__7',
#   'pid': 263818,
#   'rel': '/government/politician/government_positions_held./government/government_position_held/legislative_sessions',
#   'rid': 93,
#   'subj': '/m/0226cw'},
#  {'obj': '/m/01vsl3_',
#   'pid': 263819,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/02yv6b'},
#  {'obj': '/m/01518s',
#   'pid': 263820,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/02yv6b'},
#  {'obj': '/m/0f2wj',
#   'pid': 263821,
#   'rel': '/people/deceased_person/place_of_death',
#   'rid': 39,
#   'subj': '/m/05f2jk'},
#  {'obj': '/m/09c7w0',
#   'pid': 263822,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/02dlfh'},
#  {'obj': '/m/0lgw7',
#   'pid': 263823,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/01n8gr'},
#  {'obj': '/m/0kq2g',
#   'pid': 263824,
#   'rel': '/location/location/adjoin_s./location/adjoining_relationship/adjoins',
#   'rid': 58,
#   'subj': '/m/0l2nd'},
#  {'obj': '/m/02pqp12',
#   'pid': 263825,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/0jgwf'},
#  {'obj': '/m/0gl02yg',
#   'pid': 263826,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/09v8db5'},
#  {'obj': '/m/01l8t8',
#   'pid': 263827,
#   'rel': '/education/educational_degree/people_with_this_degree./education/education/institution',
#   'rid': 89,
#   'subj': '/m/02h4rq6'},
#  {'obj': '/m/036k0s',
#   'pid': 263828,
#   'rel': '/people/person/place_of_birth',
#   'rid': 24,
#   'subj': '/m/049g_xj'},
#  {'obj': '/m/04ztj',
#   'pid': 263829,
#   'rel': '/people/person/spouse_s./people/marriage/type_of_union',
#   'rid': 85,
#   'subj': '/m/02h48'},
#  {'obj': '/m/0345h',
#   'pid': 263830,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/07x4qr'},
#  {'obj': '/m/05sxg2',
#   'pid': 263831,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0b7xl8'},
#  {'obj': '/m/0dxtw',
#   'pid': 263832,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/02dpl9'},
#  {'obj': '/m/06mzp',
#   'pid': 263833,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/02dpl9'},
#  {'obj': '/m/083tk',
#   'pid': 263834,
#   'rel': '/people/ethnicity/languages_spoken',
#   'rid': 214,
#   'subj': '/m/0d7wh'},
#  {'obj': '/m/02vkvcz',
#   'pid': 263835,
#   'rel': '/people/ethnicity/people',
#   'rid': 71,
#   'subj': '/m/0d7wh'},
#  {'obj': '/m/09s1f',
#   'pid': 263836,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/0b1xl'},
#  {'obj': '/m/0r5y9',
#   'pid': 263837,
#   'rel': '/people/person/place_of_birth',
#   'rid': 24,
#   'subj': '/m/03lmzl'},
#  {'obj': '/m/077qn',
#   'pid': 263838,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/01cgz'},
#  {'obj': '/m/01xbgx',
#   'pid': 263839,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/01cgz'},
#  {'obj': '/m/0325pb',
#   'pid': 263840,
#   'rel': '/education/university/fraternities_and_sororities',
#   'rid': 217,
#   'subj': '/m/01swxv'},
#  {'obj': '/m/07fb8_',
#   'pid': 263841,
#   'rel': '/film/film/film_format',
#   'rid': 115,
#   'subj': '/m/0_9l_'},
#  {'obj': '/m/0bw6y',
#   'pid': 263842,
#   'rel': '/award/award_category/winners./award/award_honor/award_winner',
#   'rid': 47,
#   'subj': '/m/02py7pj'},
#  {'obj': '/m/01fx4k',
#   'pid': 263843,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0gs9p'},
#  {'obj': '/m/0jym0',
#   'pid': 263844,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0gs9p'},
#  {'obj': '/m/0395lw',
#   'pid': 263845,
#   'rel': '/music/artist/track_contributions./music/track_contribution/role',
#   'rid': 41,
#   'subj': '/m/01304j'},
#  {'obj': '/m/02hrh1q',
#   'pid': 263846,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/01309x'},
#  {'obj': '/m/01pb34',
#   'pid': 263847,
#   'rel': '/film/actor/film./film/performance/special_performance_type',
#   'rid': 212,
#   'subj': '/m/01l3j'},
#  {'obj': '/m/01mkq',
#   'pid': 263848,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/015fs3'},
#  {'obj': '/m/0np9r',
#   'pid': 263849,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/01trf3'},
#  {'obj': '/m/09306z',
#   'pid': 263850,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/0gq_v'},
#  {'obj': '/m/05qjt',
#   'pid': 263851,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/01trxd'},
#  {'obj': '/m/0k049',
#   'pid': 263852,
#   'rel': '/location/location/contains',
#   'rid': 15,
#   'subj': '/m/030qb3t'},
#  {'obj': '/m/02hrh1q',
#   'pid': 263853,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0m68w'},
#  {'obj': '/m/02jx1',
#   'pid': 263854,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/0j_c'},
#  {'obj': '/m/01jrbv',
#   'pid': 263855,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/03hkv_r'},
#  {'obj': '/m/088cp',
#   'pid': 263856,
#   'rel': '/people/person/place_of_birth',
#   'rid': 24,
#   'subj': '/m/0lpjn'},
#  {'obj': '/m/04n3l',
#   'pid': 263857,
#   'rel': '/people/person/places_lived./people/place_lived/location',
#   'rid': 66,
#   'subj': '/m/013w7j'},
#  {'obj': '/m/0ch3qr1',
#   'pid': 263858,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/06rq2l'},
#  {'obj': '/m/0kbvb',
#   'pid': 263859,
#   'rel': '/olympics/olympic_participating_country/athletes./olympics/olympic_athlete_affiliation/olympics',
#   'rid': 72,
#   'subj': '/m/0h3y'},
#  {'obj': '/m/02kdv5l',
#   'pid': 263860,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/01f8hf'},
#  {'obj': '/m/0ctw_b',
#   'pid': 263861,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/02bfxb'},
#  {'obj': '/m/0k6nt',
#   'pid': 263862,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0661ql3'},
#  {'obj': '/m/02tr7d',
#   'pid': 252620,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/03v3xp'},
#  {'obj': '/m/03_9r',
#   'pid': 263863,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/0pc62'},
#  {'obj': '/m/01mw1',
#   'pid': 263864,
#   'rel': '/business/business_operation/industry',
#   'rid': 46,
#   'subj': '/m/01qszl'},
#  {'obj': '/m/06m6z6',
#   'pid': 263865,
#   'rel': '/film/film/executive_produced_by',
#   'rid': 136,
#   'subj': '/m/034qzw'},
#  {'obj': '/m/01q_wyj',
#   'pid': 263866,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/01trtc'},
#  {'obj': '/m/07t65',
#   'pid': 263867,
#   'rel': '/organization/organization_member/member_of./organization/organization_membership/organization',
#   'rid': 23,
#   'subj': '/m/01ppq'},
#  {'obj': '/m/0688f',
#   'pid': 263868,
#   'rel': '/people/person/languages',
#   'rid': 100,
#   'subj': '/m/08d6bd'},
#  {'obj': '/m/01t6b4',
#   'pid': 263869,
#   'rel': '/education/educational_institution/students_graduates./education/education/student',
#   'rid': 22,
#   'subj': '/m/07vyf'},
#  {'obj': '/m/0kszw',
#   'pid': 263870,
#   'rel': '/award/award_winning_work/awards_won./award/award_honor/award_winner',
#   'rid': 12,
#   'subj': '/m/09gq0x5'},
#  {'obj': '/m/0hwqg',
#   'pid': 263871,
#   'rel': '/people/ethnicity/people',
#   'rid': 71,
#   'subj': '/m/013b6_'},
#  {'obj': '/m/064_8sq',
#   'pid': 263872,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/0kv9d3'},
#  {'obj': '/m/09c7w0',
#   'pid': 263873,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/030pr'},
#  {'obj': '/m/03mr85',
#   'pid': 263874,
#   'rel': '/film/film_set_designer/film_sets_designed',
#   'rid': 173,
#   'subj': '/m/076psv'},
#  {'obj': '/m/07_fj54',
#   'pid': 263875,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/09yhzs'},
#  {'obj': '/m/01hv3t',
#   'pid': 263876,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/05ztjjw'},
#  {'obj': '/m/015qh',
#   'pid': 263877,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/0dwxr'},
#  {'obj': '/m/03qbnj',
#   'pid': 263878,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/02w4fkq'},
#  {'obj': '/m/09nqf',
#   'pid': 263879,
#   'rel': '/film/film/estimated_budget./measurement_unit/dated_money_value/currency',
#   'rid': 34,
#   'subj': '/m/06bd5j'},
#  {'obj': '/m/047dpm0',
#   'pid': 263880,
#   'rel': '/sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/draft',
#   'rid': 96,
#   'subj': '/m/05xvj'},
#  {'obj': '/m/0jjw',
#   'pid': 263881,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/07w0v'},
#  {'obj': '/m/09nqf',
#   'pid': 263882,
#   'rel': '/base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency',
#   'rid': 60,
#   'subj': '/m/018ygt'},
#  {'obj': '/m/0rh6k',
#   'pid': 263883,
#   'rel': '/film/film/featured_film_locations',
#   'rid': 106,
#   'subj': '/m/011wtv'},
#  {'obj': '/m/092vkg',
#   'pid': 263884,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02pqp12'},
#  {'obj': '/m/07kg3',
#   'pid': 263885,
#   'rel': '/people/person/spouse_s./people/marriage/location_of_ceremony',
#   'rid': 224,
#   'subj': '/m/0m31m'},
#  {'obj': '/m/01jnf1',
#   'pid': 263886,
#   'rel': '/education/educational_institution/colors',
#   'rid': 61,
#   'subj': '/m/015q1n'},
#  {'obj': '/m/02hrh1q',
#   'pid': 263887,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/045g4l'},
#  {'obj': '/m/05r3qc',
#   'pid': 263888,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/01kwsg'},
#  {'obj': '/m/025352',
#   'pid': 263889,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/029h45'},
#  {'obj': '/m/027rn',
#   'pid': 263890,
#   'rel': '/people/person/places_lived./people/place_lived/location',
#   'rid': 66,
#   'subj': '/m/01sl1q'},
#  {'obj': '/m/07z31v',
#   'pid': 263891,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/0bdx29'},
#  {'obj': '/m/02h40lc',
#   'pid': 263892,
#   'rel': '/people/person/languages',
#   'rid': 100,
#   'subj': '/m/0bt7ws'},
#  {'obj': '/m/0ckd1',
#   'pid': 263893,
#   'rel': '/tv/tv_producer/programs_produced./tv/tv_producer_term/producer_type',
#   'rid': 110,
#   'subj': '/m/05gp3x'},
#  {'obj': '/m/09zzb8',
#   'pid': 263894,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/017d93'},
#  {'obj': '/m/019f4v',
#   'pid': 263895,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/06mn7'},
#  {'obj': '/m/09gq0x5',
#   'pid': 263896,
#   'rel': '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film',
#   'rid': 32,
#   'subj': '/m/017s11'},
#  {'obj': '/m/016dj8',
#   'pid': 263897,
#   'rel': '/film/film_distributor/films_distributed./film/film_film_distributor_relationship/film',
#   'rid': 32,
#   'subj': '/m/017s11'},
#  {'obj': '/m/0cvw9',
#   'pid': 263898,
#   'rel': '/film/film/featured_film_locations',
#   'rid': 106,
#   'subj': '/m/08g_jw'},
#  {'obj': '/m/0ch26b_',
#   'pid': 263899,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02r0csl'},
#  {'obj': '/m/01mr2g6',
#   'pid': 263900,
#   'rel': '/music/instrument/instrumentalists',
#   'rid': 42,
#   'subj': '/m/03qjg'},
#  {'obj': '/m/05tbn',
#   'pid': 263901,
#   'rel': '/government/legislative_session/members./government/government_position_held/district_represented',
#   'rid': 35,
#   'subj': '/m/024tkd'},
#  {'obj': '/m/04ztj',
#   'pid': 263902,
#   'rel': '/people/person/spouse_s./people/marriage/type_of_union',
#   'rid': 85,
#   'subj': '/m/09p0q'},
#  {'obj': '/m/034b6k',
#   'pid': 263903,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02g3v6'},
#  {'obj': '/m/06f41',
#   'pid': 263904,
#   'rel': '/user/jg/default_domain/olympic_games/sports',
#   'rid': 174,
#   'subj': '/m/0l6vl'},
#  {'obj': '/m/046lt',
#   'pid': 263905,
#   'rel': '/medicine/disease/notable_people_with_this_condition',
#   'rid': 149,
#   'subj': '/m/029sk'},
#  {'obj': '/m/04ztj',
#   'pid': 263906,
#   'rel': '/people/person/spouse_s./people/marriage/type_of_union',
#   'rid': 85,
#   'subj': '/m/026n9h3'},
#  {'obj': '/m/05v8c',
#   'pid': 263907,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/067ghz'},
#  {'obj': '/m/0349s',
#   'pid': 263908,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/0272_vz'},
#  {'obj': '/m/02pyyld',
#   'pid': 263909,
#   'rel': '/base/marchmadness/ncaa_basketball_tournament/seeds./base/marchmadness/ncaa_tournament_seed/team',
#   'rid': 176,
#   'subj': '/m/0b_6mr'},
#  {'obj': '/m/033smt',
#   'pid': 263910,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/08phg9'},
#  {'obj': '/m/02hrh1q',
#   'pid': 263911,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/080knyg'},
#  {'obj': '/m/05r4w',
#   'pid': 263912,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0ds6bmk'},
#  {'obj': '/m/03spz',
#   'pid': 263913,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/016k62'},
#  {'obj': '/m/08c9b0',
#   'pid': 263914,
#   'rel': '/film/film/music',
#   'rid': 116,
#   'subj': '/m/03bx2lk'},
#  {'obj': '/m/02zsn',
#   'pid': 263915,
#   'rel': '/people/person/gender',
#   'rid': 43,
#   'subj': '/m/023s8'},
#  {'obj': '/m/02vr7',
#   'pid': 263916,
#   'rel': '/music/instrument/instrumentalists',
#   'rid': 42,
#   'subj': '/m/07xzm'},
#  {'obj': '/m/059j2',
#   'pid': 263917,
#   'rel': '/location/location/partially_contains',
#   'rid': 222,
#   'subj': '/m/0157g9'},
#  {'obj': '/m/02rh1dz',
#   'pid': 263918,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/03cd0x'},
#  {'obj': '/m/03gjzk',
#   'pid': 263919,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/090gpr'},
#  {'obj': '/m/04jpl',
#   'pid': 263920,
#   'rel': '/people/person/places_lived./people/place_lived/location',
#   'rid': 66,
#   'subj': '/m/03k545'},
#  {'obj': '/m/07s9rl0',
#   'pid': 263921,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/0ds2l81'},
#  {'obj': '/m/08mbj5d',
#   'pid': 263922,
#   'rel': '/common/topic/webpage./common/webpage/category',
#   'rid': 25,
#   'subj': '/m/01vv6xv'},
#  {'obj': '/m/02_7t',
#   'pid': 263923,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/05x_5'},
#  {'obj': '/m/07hhnl',
#   'pid': 263924,
#   'rel': '/film/film/film_art_direction_by',
#   'rid': 223,
#   'subj': '/m/02r_pp'},
#  {'obj': '/m/07f1x',
#   'pid': 263925,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0gvrws1'},
#  {'obj': '/m/01vrt_c',
#   'pid': 263926,
#   'rel': '/award/award_category/winners./award/award_honor/award_winner',
#   'rid': 47,
#   'subj': '/m/02f77y'},
#  {'obj': '/m/016z4k',
#   'pid': 263927,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/09889g'},
#  {'obj': '/m/02h40lc',
#   'pid': 263928,
#   'rel': '/people/person/languages',
#   'rid': 100,
#   'subj': '/m/03_l8m'},
#  {'obj': '/m/03115z',
#   'pid': 263929,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/027m67'},
#  {'obj': '/m/03rj0',
#   'pid': 263930,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/03q0r1'},
#  {'obj': '/m/01vvycq',
#   'pid': 263931,
#   'rel': '/broadcast/content/artist',
#   'rid': 233,
#   'subj': '/m/04rqd'},
#  {'obj': '/m/083jv',
#   'pid': 263932,
#   'rel': '/sports/sports_team/colors',
#   'rid': 95,
#   'subj': '/m/07147'},
#  {'obj': '/m/02kdv5l',
#   'pid': 263933,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/0jvt9'},
#  {'obj': '/m/028qdb',
#   'pid': 263934,
#   'rel': '/music/instrument/instrumentalists',
#   'rid': 42,
#   'subj': '/m/05r5c'},
#  {'obj': '/m/0jqd3',
#   'pid': 263935,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0gr51'},
#  {'obj': '/m/0nbjq',
#   'pid': 263936,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/olympics',
#   'rid': 104,
#   'subj': '/m/01sgl'},
#  {'obj': '/m/035qy',
#   'pid': 263937,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/01sgl'},
#  {'obj': '/m/01c72t',
#   'pid': 263938,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/03975z'},
#  {'obj': '/m/01jgkj2',
#   'pid': 263939,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/03rhqg'},
#  {'obj': '/m/03h64',
#   'pid': 263940,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/06tpmy'},
#  {'obj': '/m/01d_h8',
#   'pid': 263941,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/01v5h'},
#  {'obj': '/m/0345h',
#   'pid': 263942,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0cbn7c'},
#  {'obj': '/m/0416y94',
#   'pid': 263943,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0gqwc'},
#  {'obj': '/m/01v40wd',
#   'pid': 263944,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/0glt670'},
#  {'obj': '/m/05qbckf',
#   'pid': 263945,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/nominated_for',
#   'rid': 38,
#   'subj': '/m/02m501'},
#  {'obj': '/m/0b90_r',
#   'pid': 263946,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/04cppj'},
#  {'obj': '/m/021lby',
#   'pid': 263947,
#   'rel': '/film/film/executive_produced_by',
#   'rid': 136,
#   'subj': '/m/0d90m'},
#  {'obj': '/m/04m8fy',
#   'pid': 263948,
#   'rel': '/education/university/fraternities_and_sororities',
#   'rid': 217,
#   'subj': '/m/0cwx_'},
#  {'obj': '/m/03kx49',
#   'pid': 263949,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/021b_'},
#  {'obj': '/m/0q8p8',
#   'pid': 263950,
#   'rel': '/location/hud_county_place/place',
#   'rid': 56,
#   'subj': '/m/0q8p8'},
#  {'obj': '/m/03h64',
#   'pid': 263951,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0m3gy'},
#  {'obj': '/m/0373qt',
#   'pid': 263952,
#   'rel': '/education/educational_degree/people_with_this_degree./education/education/institution',
#   'rid': 89,
#   'subj': '/m/0bkj86'},
#  {'obj': '/m/01vsy95',
#   'pid': 263953,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/0fb0v'},
#  {'obj': '/m/03spz',
#   'pid': 263954,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/064lsn'},
#  {'obj': '/m/060__y',
#   'pid': 263955,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/0b2qtl'},
#  {'obj': '/m/0chghy',
#   'pid': 263956,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/02ylg6'},
#  {'obj': '/m/05zppz',
#   'pid': 263957,
#   'rel': '/people/person/gender',
#   'rid': 43,
#   'subj': '/m/07m69t'},
#  {'obj': '/m/03bxz7',
#   'pid': 263958,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/0cnztc4'},
#  {'obj': '/m/05r4w',
#   'pid': 263959,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0cnztc4'},
#  {'obj': '/m/026xxv_',
#   'pid': 263960,
#   'rel': '/base/marchmadness/ncaa_basketball_tournament/seeds./base/marchmadness/ncaa_tournament_seed/team',
#   'rid': 176,
#   'subj': '/m/0b_6qj'},
#  {'obj': '/m/09sb52',
#   'pid': 263961,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/07rhpg'},
#  {'obj': '/m/0cj16',
#   'pid': 263962,
#   'rel': '/film/film/film_format',
#   'rid': 115,
#   'subj': '/m/0hmm7'},
#  {'obj': '/m/03cx282',
#   'pid': 263963,
#   'rel': '/film/film/cinematography',
#   'rid': 183,
#   'subj': '/m/047wh1'},
#  {'obj': '/m/073hmq',
#   'pid': 263964,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/0gq_d'},
#  {'obj': '/m/02kcv4x',
#   'pid': 263965,
#   'rel': '/food/food/nutrients./food/nutrition_fact/nutrient',
#   'rid': 137,
#   'subj': '/m/07j87'},
#  {'obj': '/m/02rh1dz',
#   'pid': 263966,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/0bv8h2'},
#  {'obj': '/m/019l68',
#   'pid': 263967,
#   'rel': '/award/award_category/winners./award/award_honor/award_winner',
#   'rid': 47,
#   'subj': '/m/0bdwft'},
#  {'obj': '/m/04bbv7',
#   'pid': 263968,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/01243b'},
#  {'obj': '/m/02ndj5',
#   'pid': 263969,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/01243b'},
#  {'obj': '/m/016l09',
#   'pid': 263970,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/01243b'},
#  {'obj': '/m/09c7w0',
#   'pid': 263971,
#   'rel': '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_location',
#   'rid': 150,
#   'subj': '/m/01s73z'},
#  {'obj': '/m/029g_vk',
#   'pid': 263972,
#   'rel': '/business/business_operation/industry',
#   'rid': 46,
#   'subj': '/m/01s73z'},
#  {'obj': '/m/08mbj5d',
#   'pid': 263973,
#   'rel': '/common/topic/webpage./common/webpage/category',
#   'rid': 25,
#   'subj': '/m/01sg4_'},
#  {'obj': '/m/0jbk9',
#   'pid': 263974,
#   'rel': '/location/hud_foreclosure_area/estimated_number_of_mortgages./measurement_unit/dated_integer/source',
#   'rid': 120,
#   'subj': '/m/0jgk3'},
#  {'obj': '/m/08mbj5d',
#   'pid': 263975,
#   'rel': '/common/topic/webpage./common/webpage/category',
#   'rid': 25,
#   'subj': '/m/01d4cb'},
#  {'obj': '/m/08yx9q',
#   'pid': 263976,
#   'rel': '/award/award_ceremony/awards_presented./award/award_honor/award_winner',
#   'rid': 27,
#   'subj': '/m/0275n3y'},
#  {'obj': '/m/0hvb2',
#   'pid': 263977,
#   'rel': '/award/award_ceremony/awards_presented./award/award_honor/award_winner',
#   'rid': 27,
#   'subj': '/m/0275n3y'},
#  {'obj': '/m/01d2v1',
#   'pid': 263978,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02hsq3m'},
#  {'obj': '/m/0fpjyd',
#   'pid': 263979,
#   'rel': '/film/film/music',
#   'rid': 116,
#   'subj': '/m/02wwmhc'},
#  {'obj': '/m/04f0xq',
#   'pid': 263980,
#   'rel': '/organization/role/leaders./organization/leadership/organization',
#   'rid': 63,
#   'subj': '/m/0dq_5'},
#  {'obj': '/m/01frpd',
#   'pid': 263981,
#   'rel': '/organization/role/leaders./organization/leadership/organization',
#   'rid': 63,
#   'subj': '/m/0dq_5'},
#  {'obj': '/m/07zlqp',
#   'pid': 263982,
#   'rel': '/organization/role/leaders./organization/leadership/organization',
#   'rid': 63,
#   'subj': '/m/0dq_5'},
#  {'obj': '/m/01crd5',
#   'pid': 263983,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/071t0'},
#  {'obj': '/m/07ww5',
#   'pid': 263984,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/071t0'},
#  {'obj': '/m/050ks',
#   'pid': 263985,
#   'rel': '/government/legislative_session/members./government/government_position_held/district_represented',
#   'rid': 35,
#   'subj': '/m/02bn_p'},
#  {'obj': '/m/03x42',
#   'pid': 263986,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/09gkx35'},
#  {'obj': '/m/013719',
#   'pid': 263987,
#   'rel': '/education/educational_degree/people_with_this_degree./education/education/institution',
#   'rid': 89,
#   'subj': '/m/02_xgp2'},
#  {'obj': '/m/07x4qr',
#   'pid': 263988,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/08hsww'},
#  {'obj': '/m/02ynfr',
#   'pid': 263989,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/02cbhg'},
#  {'obj': '/m/0dh73w',
#   'pid': 263990,
#   'rel': '/film/film/film_production_design_by',
#   'rid': 184,
#   'subj': '/m/04q827'},
#  {'obj': '/m/02hrh1q',
#   'pid': 263991,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/030znt'},
#  {'obj': '/m/0422v0',
#   'pid': 263992,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/030znt'},
#  {'obj': '/m/04ztj',
#   'pid': 263993,
#   'rel': '/people/person/spouse_s./people/marriage/type_of_union',
#   'rid': 85,
#   'subj': '/m/0bwgc_'},
#  {'obj': '/m/09jg8',
#   'pid': 263994,
#   'rel': '/medicine/symptom/symptom_of',
#   'rid': 216,
#   'subj': '/m/0hgxh'},
#  {'obj': '/m/01m3b1t',
#   'pid': 263995,
#   'rel': '/film/film/music',
#   'rid': 116,
#   'subj': '/m/09rsjpv'},
#  {'obj': '/m/030qb3t',
#   'pid': 263996,
#   'rel': '/film/film/featured_film_locations',
#   'rid': 106,
#   'subj': '/m/0435vm'},
#  {'obj': '/m/0djd3',
#   'pid': 263997,
#   'rel': '/people/person/place_of_birth',
#   'rid': 24,
#   'subj': '/m/02wb6yq'},
#  {'obj': '/m/07b_l',
#   'pid': 263998,
#   'rel': '/people/person/places_lived./people/place_lived/location',
#   'rid': 66,
#   'subj': '/m/02wb6yq'},
#  {'obj': '/m/0jsf6',
#   'pid': 263999,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/019f4v'},
#  {'obj': '/m/0345h',
#   'pid': 264000,
#   'rel': '/film/film/featured_film_locations',
#   'rid': 106,
#   'subj': '/m/072x7s'},
#  {'obj': '/m/01nyl',
#   'pid': 264001,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/0w0d'},
#  {'obj': '/m/01585b',
#   'pid': 264002,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/0c9t0y'},
#  {'obj': '/m/0jgd',
#   'pid': 264003,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/07rlg'},
#  {'obj': '/m/02k1b',
#   'pid': 264004,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/01lb14'},
#  {'obj': '/m/01zlh5',
#   'pid': 264005,
#   'rel': '/people/cause_of_death/people',
#   'rid': 50,
#   'subj': '/m/0gk4g'},
#  {'obj': '/m/014_xj',
#   'pid': 264006,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/01dtcb'},
#  {'obj': '/m/0ch6mp2',
#   'pid': 264007,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/017180'},
#  {'obj': '/m/04bbv7',
#   'pid': 264008,
#   'rel': '/film/film/dubbing_performances./film/dubbing_performance/actor',
#   'rid': 227,
#   'subj': '/m/0dd6bf'},
#  {'obj': '/m/02rzdcp',
#   'pid': 264009,
#   'rel': '/award/award_ceremony/awards_presented./award/award_honor/honored_for',
#   'rid': 103,
#   'subj': '/m/058m5m4'},
#  {'obj': '/m/0jzphpx',
#   'pid': 264010,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/025m8l'},
#  {'obj': '/m/014zfs',
#   'pid': 264011,
#   'rel': '/influence/influence_node/influenced_by',
#   'rid': 21,
#   'subj': '/m/019vgs'},
#  {'obj': '/m/0p7qm',
#   'pid': 264012,
#   'rel': '/film/film_subject/films',
#   'rid': 59,
#   'subj': '/m/0f6rc'},
#  {'obj': '/m/04ztj',
#   'pid': 264013,
#   'rel': '/people/person/spouse_s./people/marriage/type_of_union',
#   'rid': 85,
#   'subj': '/m/03d2k'},
#  {'obj': '/m/07jnt',
#   'pid': 264014,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0f4x7'},
#  {'obj': '/m/02p86pb',
#   'pid': 264015,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0f4x7'},
#  {'obj': '/m/09gb_4p',
#   'pid': 264016,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0f4x7'},
#  {'obj': '/m/05hmp6',
#   'pid': 264017,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/0f4x7'},
#  {'obj': '/m/0jmbv',
#   'pid': 264018,
#   'rel': '/sports/pro_athlete/teams./sports/sports_team_roster/team',
#   'rid': 40,
#   'subj': '/m/03lh3v'},
#  {'obj': '/m/02h40lc',
#   'pid': 264019,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/0243cq'},
#  {'obj': '/m/03yj_0n',
#   'pid': 253218,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/027dtv3'},
#  {'obj': '/m/019mcm',
#   'pid': 264020,
#   'rel': '/sports/sports_team_location/teams',
#   'rid': 94,
#   'subj': '/m/06gmr'},
#  {'obj': '/m/059t8',
#   'pid': 264021,
#   'rel': '/government/legislative_session/members./government/government_position_held/district_represented',
#   'rid': 35,
#   'subj': '/m/034_7s'},
#  {'obj': '/m/09c7w0',
#   'pid': 264022,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/01mvth'},
#  {'obj': '/m/0325pb',
#   'pid': 264023,
#   'rel': '/education/university/fraternities_and_sororities',
#   'rid': 217,
#   'subj': '/m/01n_g9'},
#  {'obj': '/m/05dss7',
#   'pid': 264024,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/01twdk'},
#  {'obj': '/m/04165w',
#   'pid': 264025,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/09sb52'},
#  {'obj': '/m/0137g1',
#   'pid': 264026,
#   'rel': '/music/instrument/instrumentalists',
#   'rid': 42,
#   'subj': '/m/02hnl'},
#  {'obj': '/m/01vng3b',
#   'pid': 264027,
# ...
#   'rid': 154,
#   'subj': '/m/0k6nt'},
#  {'obj': '/m/09f2j',
#   'pid': 264569,
#   'rel': '/sports/sports_league_draft/picks./sports/sports_league_draft_pick/school',
#   'rid': 79,
#   'subj': '/m/09l0x9'},
#  {'obj': '/m/01d_h8',
#   'pid': 264570,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/034hck'},
#  {'obj': '/m/08c9b0',
#   'pid': 264571,
#   'rel': '/people/ethnicity/people',
#   'rid': 71,
#   'subj': '/m/03lmx1'},
#  {'obj': '/m/02zfdp',
#   'pid': 264572,
#   'rel': '/award/award_ceremony/awards_presented./award/award_honor/award_winner',
#   'rid': 27,
#   'subj': '/m/09p2r9'},
#  {'obj': '/m/0hfjk',
#   'pid': 264573,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/0gfh84d'},
#  {'obj': '/m/09c7w0',
#   'pid': 264574,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0gh8zks'},
#  {'obj': '/m/01b_lz',
#   'pid': 264575,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/nominated_for',
#   'rid': 38,
#   'subj': '/m/01fx5l'},
#  {'obj': '/m/0416y94',
#   'pid': 264576,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/03hkv_r'},
#  {'obj': '/m/062z7',
#   'pid': 264577,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/01p896'},
#  {'obj': '/m/02dpl9',
#   'pid': 264578,
#   'rel': '/media_common/netflix_genre/titles',
#   'rid': 2,
#   'subj': '/m/01hmnh'},
#  {'obj': '/m/017jd9',
#   'pid': 264579,
#   'rel': '/media_common/netflix_genre/titles',
#   'rid': 2,
#   'subj': '/m/01hmnh'},
#  {'obj': '/m/0dxtg',
#   'pid': 264580,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/06rq2l'},
#  {'obj': '/m/0b1y_2',
#   'pid': 264581,
#   'rel': '/film/special_film_performance_type/film_performance_type./film/performance/film',
#   'rid': 55,
#   'subj': '/m/09_gdc'},
#  {'obj': '/m/0kyk',
#   'pid': 264582,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0dq9wx'},
#  {'obj': '/m/03rk0',
#   'pid': 264583,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/0f2c8g'},
#  {'obj': '/m/08nvyr',
#   'pid': 264584,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/0dlglj'},
#  {'obj': '/m/03rk0',
#   'pid': 264585,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/03f22dp'},
#  {'obj': '/m/02hrh1q',
#   'pid': 264586,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0pgjm'},
#  {'obj': '/m/02pptm',
#   'pid': 264587,
#   'rel': '/sports/professional_sports_team/draft_picks./sports/sports_league_draft_pick/school',
#   'rid': 68,
#   'subj': '/m/07l4z'},
#  {'obj': '/m/02hrh1q',
#   'pid': 264588,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0d6d2'},
#  {'obj': '/m/06myp',
#   'pid': 264589,
#   'rel': '/people/ethnicity/people',
#   'rid': 71,
#   'subj': '/m/013b6_'},
#  {'obj': '/m/05zppz',
#   'pid': 264590,
#   'rel': '/people/person/gender',
#   'rid': 43,
#   'subj': '/m/03d63lb'},
#  {'obj': '/m/018p5f',
#   'pid': 264591,
#   'rel': '/business/job_title/people_with_this_title./business/employment_tenure/company',
#   'rid': 44,
#   'subj': '/m/0krdk'},
#  {'obj': '/m/02h40lc',
#   'pid': 264592,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/02gqm3'},
#  {'obj': '/m/07024',
#   'pid': 264593,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/05ztjjw'},
#  {'obj': '/m/047lj',
#   'pid': 264594,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/0dwxr'},
#  {'obj': '/m/023kzp',
#   'pid': 264595,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/05cx7x'},
#  {'obj': '/m/038hg',
#   'pid': 264596,
#   'rel': '/sports/sports_team/colors',
#   'rid': 95,
#   'subj': '/m/03mqj_'},
#  {'obj': '/m/03f5mt',
#   'pid': 264597,
#   'rel': '/music/performance_role/regular_performances./music/group_membership/role',
#   'rid': 9,
#   'subj': '/m/0l14qv'},
#  {'obj': '/m/0bfvd4',
#   'pid': 264598,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/018ygt'},
#  {'obj': '/m/01309x',
#   'pid': 264599,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/043g7l'},
#  {'obj': '/m/06npd',
#   'pid': 264600,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/02yvct'},
#  {'obj': '/m/01m15br',
#   'pid': 264601,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/01lyv'},
#  {'obj': '/m/018gz8',
#   'pid': 264602,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/03k48_'},
#  {'obj': '/m/02hcv8',
#   'pid': 264603,
#   'rel': '/location/location/time_zones',
#   'rid': 154,
#   'subj': '/m/0ply0'},
#  {'obj': '/m/030qb3t',
#   'pid': 264604,
#   'rel': '/people/person/spouse_s./people/marriage/location_of_ceremony',
#   'rid': 224,
#   'subj': '/m/058frd'},
#  {'obj': '/m/0bl2g',
#   'pid': 264605,
#   'rel': '/people/ethnicity/people',
#   'rid': 71,
#   'subj': '/m/041rx'},
#  {'obj': '/m/06rq2l',
#   'pid': 264606,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/017s11'},
#  {'obj': '/m/073bb',
#   'pid': 264607,
#   'rel': '/influence/influence_node/influenced_by',
#   'rid': 21,
#   'subj': '/m/0484q'},
#  {'obj': '/m/09vw2b7',
#   'pid': 264608,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/08g_jw'},
#  {'obj': '/m/05567m',
#   'pid': 264609,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02r0csl'},
#  {'obj': '/m/0ctw_b',
#   'pid': 264610,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0btpm6'},
#  {'obj': '/m/0btpm6',
#   'pid': 264611,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02g3v6'},
#  {'obj': '/m/015h31',
#   'pid': 264612,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/01vl17'},
#  {'obj': '/m/0b9rdk',
#   'pid': 264613,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/07cbcy'},
#  {'obj': '/m/04gc2',
#   'pid': 264614,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/07cbs'},
#  {'obj': '/m/02l7c8',
#   'pid': 264615,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/0gnjh'},
#  {'obj': '/m/09nqf',
#   'pid': 264616,
#   'rel': '/film/film/estimated_budget./measurement_unit/dated_money_value/currency',
#   'rid': 34,
#   'subj': '/m/0gnjh'},
#  {'obj': '/m/0fbtbt',
#   'pid': 264617,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/0b05xm'},
#  {'obj': '/m/03902',
#   'pid': 264618,
#   'rel': '/people/person/place_of_birth',
#   'rid': 24,
#   'subj': '/m/07cn2c'},
#  {'obj': '/m/01gp_d',
#   'pid': 264619,
#   'rel': '/base/schemastaging/organization_extra/phone_number./base/schemastaging/phone_sandbox/service_language',
#   'rid': 198,
#   'subj': '/m/05b5c'},
#  {'obj': '/m/0bdwft',
#   'pid': 264620,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/01x4sb'},
#  {'obj': '/m/09zzb8',
#   'pid': 264621,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/03qcfvw'},
#  {'obj': '/m/01f8f7',
#   'pid': 264622,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02z0dfh'},
#  {'obj': '/m/04ztj',
#   'pid': 264623,
#   'rel': '/people/person/spouse_s./people/marriage/type_of_union',
#   'rid': 85,
#   'subj': '/m/01gzm2'},
#  {'obj': '/m/09hy79',
#   'pid': 264624,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/01vwllw'},
#  {'obj': '/m/04n6k',
#   'pid': 264625,
#   'rel': '/user/tsegaran/random/taxonomy_subject/entry./user/tsegaran/random/taxonomy_entry/taxonomy',
#   'rid': 118,
#   'subj': '/m/07t21'},
#  {'obj': '/m/05zppz',
#   'pid': 264626,
#   'rel': '/people/person/gender',
#   'rid': 43,
#   'subj': '/m/0kxbc'},
#  {'obj': '/m/01vx2h',
#   'pid': 264627,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/047bynf'},
#  {'obj': '/m/06cgy',
#   'pid': 264628,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/01v80y'},
#  {'obj': '/m/0bzk2h',
#   'pid': 264629,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/0gvx_'},
#  {'obj': '/m/015h31',
#   'pid': 264630,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0250f'},
#  {'obj': '/m/015zxh',
#   'pid': 264631,
#   'rel': '/people/deceased_person/place_of_death',
#   'rid': 39,
#   'subj': '/m/06w38l'},
#  {'obj': '/m/05zppz',
#   'pid': 264632,
#   'rel': '/people/person/gender',
#   'rid': 43,
#   'subj': '/m/0gct_'},
#  {'obj': '/m/082gq',
#   'pid': 264633,
#   'rel': '/film/film/genre',
#   'rid': 31,
#   'subj': '/m/02__34'},
#  {'obj': '/m/017lb_',
#   'pid': 264634,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/016ybr'},
#  {'obj': '/m/01d_h8',
#   'pid': 264635,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0h5f5n'},
#  {'obj': '/m/0dgd_',
#   'pid': 264636,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0693l'},
#  {'obj': '/m/073tm9',
#   'pid': 264637,
#   'rel': '/organization/organization/child./organization/organization_relationship/child',
#   'rid': 207,
#   'subj': '/m/04fc6c'},
#  {'obj': '/m/0d6d2',
#   'pid': 264638,
#   'rel': '/people/cause_of_death/people',
#   'rid': 50,
#   'subj': '/m/04p3w'},
#  {'obj': '/m/04n65n',
#   'pid': 264639,
#   'rel': '/music/genre/artists',
#   'rid': 20,
#   'subj': '/m/06cp5'},
#  {'obj': '/m/029j_',
#   'pid': 264640,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_distribution_medium',
#   'rid': 11,
#   'subj': '/m/0dqcs3'},
#  {'obj': '/m/01c7y',
#   'pid': 264641,
#   'rel': '/people/person/languages',
#   'rid': 100,
#   'subj': '/m/0pj8m'},
#  {'obj': '/m/02ll45',
#   'pid': 264642,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/02r22gf'},
#  {'obj': '/m/02h9_l',
#   'pid': 264643,
#   'rel': '/award/award_category/winners./award/award_honor/award_winner',
#   'rid': 47,
#   'subj': '/m/01c427'},
#  {'obj': '/m/01shy7',
#   'pid': 264644,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/070yzk'},
#  {'obj': '/m/02_286',
#   'pid': 264645,
#   'rel': '/film/film/featured_film_locations',
#   'rid': 106,
#   'subj': '/m/03shpq'},
#  {'obj': '/m/01pjr7',
#   'pid': 264646,
#   'rel': '/education/educational_institution/students_graduates./education/education/student',
#   'rid': 22,
#   'subj': '/m/0g2jl'},
#  {'obj': '/m/09nqf',
#   'pid': 264647,
#   'rel': '/base/schemastaging/person_extra/net_worth./measurement_unit/dated_money_value/currency',
#   'rid': 60,
#   'subj': '/m/01pgzn_'},
#  {'obj': '/m/01309x',
#   'pid': 264648,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/03rhqg'},
#  {'obj': '/m/02hzz',
#   'pid': 264649,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/03rhqg'},
#  {'obj': '/m/09sb52',
#   'pid': 264650,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/02zl4d'},
#  {'obj': '/m/06mkj',
#   'pid': 264651,
#   'rel': '/film/film/release_date_s./film/film_regional_release_date/film_release_region',
#   'rid': 13,
#   'subj': '/m/0gx9rvq'},
#  {'obj': '/m/03t95n',
#   'pid': 264652,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/nominated_for',
#   'rid': 38,
#   'subj': '/m/01mkn_d'},
#  {'obj': '/m/02x1dht',
#   'pid': 264653,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/022_q8'},
#  {'obj': '/m/01p0vf',
#   'pid': 264654,
#   'rel': '/music/record_label/artist',
#   'rid': 76,
#   'subj': '/m/017l96'},
#  {'obj': '/m/0m7yy',
#   'pid': 264655,
#   'rel': '/award/award_winning_work/awards_won./award/award_honor/award',
#   'rid': 30,
#   'subj': '/m/0330r'},
#  {'obj': '/m/0bm2g',
#   'pid': 264656,
#   'rel': '/award/award_category/nominees./award/award_nomination/nominated_for',
#   'rid': 7,
#   'subj': '/m/0gqwc'},
#  {'obj': '/m/05qfh',
#   'pid': 264657,
#   'rel': '/education/educational_institution/students_graduates./education/education/major_field_of_study',
#   'rid': 101,
#   'subj': '/m/0cwx_'},
#  {'obj': '/m/019pkm',
#   'pid': 264658,
#   'rel': '/education/educational_institution/students_graduates./education/education/student',
#   'rid': 22,
#   'subj': '/m/0cwx_'},
#  {'obj': '/m/0p_pd',
#   'pid': 264659,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/01y_px'},
#  {'obj': '/m/0chghy',
#   'pid': 264660,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/019tzd'},
#  {'obj': '/m/03_xj',
#   'pid': 264661,
#   'rel': '/location/location/contains',
#   'rid': 15,
#   'subj': '/m/02qkt'},
#  {'obj': '/m/0kz2w',
#   'pid': 264662,
#   'rel': '/education/educational_degree/people_with_this_degree./education/education/institution',
#   'rid': 89,
#   'subj': '/m/0bkj86'},
#  {'obj': '/m/09p2r9',
#   'pid': 264663,
#   'rel': '/award/award_category/winners./award/award_honor/ceremony',
#   'rid': 10,
#   'subj': '/m/027s4dn'},
#  {'obj': '/m/08mbj5d',
#   'pid': 264664,
#   'rel': '/common/topic/webpage./common/webpage/category',
#   'rid': 25,
#   'subj': '/m/01xlqd'},
#  {'obj': '/m/02r96rf',
#   'pid': 264665,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/03nsm5x'},
#  {'obj': '/m/02_286',
#   'pid': 264666,
#   'rel': '/organization/organization/headquarters./location/mailing_address/citytown',
#   'rid': 83,
#   'subj': '/m/0fb0v'},
#  {'obj': '/m/04306rv',
#   'pid': 264667,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/064lsn'},
#  {'obj': '/m/07s8r0',
#   'pid': 264668,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award_nominee',
#   'rid': 8,
#   'subj': '/m/0fthdk'},
#  {'obj': '/m/02hwyss',
#   'pid': 264669,
#   'rel': '/film/film/language',
#   'rid': 14,
#   'subj': '/m/0642xf3'},
#  {'obj': '/m/06f32',
#   'pid': 264670,
#   'rel': '/olympics/olympic_games/participating_countries',
#   'rid': 157,
#   'subj': '/m/09x3r'},
#  {'obj': '/m/0km3f',
#   'pid': 264671,
#   'rel': '/base/petbreeds/city_with_dogs/top_breeds./base/petbreeds/dog_city_relationship/dog_breed',
#   'rid': 156,
#   'subj': '/m/04f_d'},
#  {'obj': '/m/04f_d',
#   'pid': 264672,
#   'rel': '/location/hud_county_place/place',
#   'rid': 56,
#   'subj': '/m/04f_d'},
#  {'obj': '/m/02l6h',
#   'pid': 264673,
#   'rel': '/education/university/domestic_tuition./measurement_unit/dated_money_value/currency',
#   'rid': 166,
#   'subj': '/m/0m7yh'},
#  {'obj': '/m/057xs89',
#   'pid': 264674,
#   'rel': '/award/award_nominee/award_nominations./award/award_nomination/award',
#   'rid': 19,
#   'subj': '/m/017r13'},
#  {'obj': '/m/04w58',
#   'pid': 264675,
#   'rel': '/olympics/olympic_sport/athletes./olympics/olympic_athlete_affiliation/country',
#   'rid': 29,
#   'subj': '/m/06f41'},
#  {'obj': '/m/01prf3',
#   'pid': 264676,
#   'rel': '/organization/organization_member/member_of./organization/organization_membership/organization',
#   'rid': 23,
#   'subj': '/m/01zwy'},
#  {'obj': '/m/02_nsc',
#   'pid': 264677,
#   'rel': '/film/actor/film./film/performance/film',
#   'rid': 6,
#   'subj': '/m/05dbf'},
#  {'obj': '/m/02hrh1q',
#   'pid': 264678,
#   'rel': '/people/person/profession',
#   'rid': 17,
#   'subj': '/m/0g28b1'},
#  {'obj': '/m/02vk52z',
#   'pid': 264679,
#   'rel': '/organization/organization_member/member_of./organization/organization_membership/organization',
#   'rid': 23,
#   'subj': '/m/04v3q'},
#  {'obj': '/m/02r96rf',
#   'pid': 264680,
#   'rel': '/film/film/other_crew./film/film_crew_gig/film_crew_role',
#   'rid': 26,
#   'subj': '/m/02tktw'},
#  {'obj': '/m/09c7w0',
#   'pid': 264681,
#   'rel': '/people/person/nationality',
#   'rid': 48,
#   'subj': '/m/070w7s'},
#  ...]

# %%
model.rate(263691,148)
# Out:
# WARNING (theano.tensor.blas): We did not found a dynamic library into the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# ValueErrorTraceback (most recent call last)
# <ipython-input-32-ed0abb131c21> in <module>()
# ----> 1 model.rate(263691,148)
#
# /home/ubuntu/pynb/fb15k-akbc/CFModel.py in rate(self, user_id, item_id)
#      26
#      27     def rate(self, user_id, item_id):
# ---> 28         return self.predict([np.array([user_id]), np.array([item_id])])[0][0]
#
# /usr/local/lib/python2.7/dist-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     462         if self.model is None:
#     463             self.build()
# --> 464         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     465
#     466     def predict_on_batch(self, x):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1153         f = self.predict_function
#    1154         return self._predict_loop(f, ins,
# -> 1155                                   batch_size=batch_size, verbose=verbose)
#    1156
#    1157     def train_on_batch(self, x, y,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose)
#     853                 ins_batch = slice_X(ins, batch_ids)
#     854
# --> 855             batch_outs = f(ins_batch)
#     856             if type(batch_outs) != list:
#     857                 batch_outs = [batch_outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     529     def __call__(self, inputs):
#     530         assert type(inputs) in {list, tuple}
# --> 531         return self.function(*inputs)
#     532
#     533
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     869                     node=self.fn.nodes[self.fn.position_of_error],
#     870                     thunk=thunk,
# --> 871                     storage_map=getattr(self.fn, 'storage_map', None))
#     872             else:
#     873                 # old-style linkers raise their own exceptions
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/link.pyc in raise_with_op(node, thunk, exc_info, storage_map)
#     312         # extra long error message in that case.
#     313         pass
# --> 314     reraise(exc_type, exc_value, exc_trace)
#     315
#     316
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# ValueError: total size of new array must be unchanged
# Apply node that caused the error: Reshape{2}(AdvancedSubtensor1.0, TensorConstant{[-1 50]})
# Toposort index: 16
# Inputs types: [TensorType(float32, matrix), TensorType(int64, vector)]
# Inputs shapes: [(1, 20), (2,)]
# Inputs strides: [(80, 4), (8,)]
# Inputs values: ['not shown', array([-1, 50])]
# Outputs clients: [[InplaceDimShuffle{0,1}(Reshape{2}.0)]]
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.

# %%
triples.head(3)
# Out:
#          subj                                                rel        obj  \
# 0    /m/08966  /travel/travel_destination/climate./travel/tra...   /m/05lf_
# 1   /m/01hww_  /music/performance_role/regular_performances./...  /m/01q99h
# 2  /m/09v3jyg  /film/film/release_date_s./film/film_regional_...  /m/0f8l9c
#
#       pid  rid
# 0  263691  148
# 1  263692   92
# 2  263693   13

# %%
entity_pairs.head(5)
# Out:
#          subj        obj  pid
# 0    /m/027rn   /m/06cx9    0
# 1   /m/017dcd  /m/06v8s0    1
# 2  /m/07s9rl0  /m/0170z3    2
# 3   /m/01sl1q  /m/044mz_    3
# 4   /m/0cnk2q  /m/02nzb8    4

# %%
x = []
for entity in entities:
    if entity in subj_idx['/m/01sl1q'].keys():
        print entity, subj_idx['/m/01sl1q'][entity]
len(x)
# Out:
# /m/09c7w0 171784
# /m/01n7q 1574663
# /m/02_286 1587424
# /m/07b_l 222038
# /m/0f2wj 1371196
# /m/027rn 263890
# /m/030qb3t 872911
# /m/03gh4 648956
# /m/01rzqj 1788071
# /m/0gsgr 2827105
# /m/0f2tj 2888182
# /m/01vq3 2667718
# /m/01vvyd8 1180479
# /m/04h9h 2612222
# /m/019pm_ 2424398
# /m/0f2w0 183894
# /m/0151ns 835523
# /m/05r7t 189971
# /m/0bth54 147213
# /m/0f4vbz 1598898
# /m/0227vl 1479822
# /m/01vw20_ 1806086
# /m/0jfx1 2887349
# /m/029j_ 885065
# /m/0cgbf 1068570
# /m/01b7h8 1393620
# /m/05qg6g 338119
# /m/06w2sn5 595257
# /m/03lt8g 1699776
# /m/08phg9 2909950
# /m/0hvb2 2668270
# /m/03v3xp 2507885
# /m/0828jw 152541
# /m/06cv1 1068571
# /m/012xdf 2873677
# /m/0c1pj 2166231
# /m/015f7 2801017
# /m/036hf4 2618462
# /m/016tw3 955114
# /m/01pgzn_ 868489
# /m/0bq2g 2507886
# /m/049qx 151042
# /m/01whg97 2777501
# /m/01f6zc 2423221
# /m/03_x5t 1699777
# /m/012vd6 2925437
# /m/01vw8mh 2028657
# /m/01lly5 2821300
# /m/01g23m 2873128
# /m/0gn30 1767766
# /m/01jfrg 1478730
# /m/01wxyx1 1180480
# /m/0436kgz 2285460
# /m/03_gd 1235462
# /m/06cgy 988787
# /m/01vwllw 2438476
# /m/05mkhs 1721264
# /m/0f5xn 1180478
# /m/02114t 2936537
# /m/01yf85 700577
# /m/022q32 60778
# /m/0h96g 338120
# /m/02k21g 2618465
# /m/0hqly 988788
# /m/018ygt 2424396
# /m/04mhxx 2160095
# /m/044mz_ 3
# /m/06x58 2160093
# /m/01f7dd 2540764
# /m/01xllf 719145
# /m/02m501 1562511
# /m/043zg 2160094
# /m/05bnp0 2936538
# /m/044mvs 215572
# /m/0mskq 2601571
# /m/019vgs 2414929
# /m/06rgq 2801022
# /m/0lk90 1478729
# /m/0170s4 1682332
# /m/017s11 2046397
# /m/016fjj 2423220
# /m/086nl7 2618463
# /m/04q827 1692672
# /m/0bksh 2285462
# /m/06lvlf 2212630
# /m/03fbb6 338121
# /m/0mb31 2635223
# /m/0dvld 2602447
# /m/01hkhq 2029891
# /m/02j490 2016945
# /m/035gjq 2424399
# /m/02s_qz 595256
# /m/01713c 2285461
# /m/0794g 992180
# /m/016xh5 2507884
# /m/04mlmx 2331445
# /m/0b68vs 2390253
# /m/06s7rd 797519
# /m/0451j 920556
# /m/0w7c 1987811
# /m/01xcr4 2676975
# /m/01qscs 2285459
# /m/043tvp3 2909949
# /m/01cj6y 2739569
# /m/01sl1q 992176
# /m/04zqmj 338122
# /m/028r4y 2641131
# /m/037d35 2987134
# /m/058s44 2438475
# /m/02zyy4 920558
# /m/03xmy1 2212974
# /m/06w6_ 2801019
# /m/02zsn 32872
# /m/019lxm 2683544
# /m/018yj6 2424397
# /m/04wp3s 2759975
# /m/025n3p 138614
# /m/01wkmgb 1806085
# /m/03_6y 2212631
# /m/01kwsg 2873676
# /m/044mjy 11793
# /m/026c1 1591802
# /m/03_wj_ 1270
# /m/02jyhv 2195028
# /m/016k6x 920557
# /m/01w61th 2541090
# /m/0bq6ntw 163985
# /m/0jlv5 2873129
# /m/01l9p 1833493
# /m/02k4gv 123131
# /m/01wbsdz 2553033
# /m/033jj1 2541091
# /m/02y_j8g 992177
# /m/016ks_ 2984479
# /m/0161sp 1894065
# /m/0ct2tf5 238571
# /m/0205dx 2749387
# /m/03pmzt 2551579
# /m/0g824 2801021
# /m/0hfml 2091334
# /m/01ccr8 2970608
# /m/03_wvl 82203
# /m/033w9g 142040
# /m/01vxxb 1258877
# /m/016z1t 2769794
# /m/03hhd3 2423222
# /m/048hf 2507887
# /m/084qpk 1925632
# /m/03_wpf 60251
# /m/02hrh1q 232955
# /m/03ds83 2697071
# /m/0259r0 2995017
# /m/06lht1 2618464
# /m/01m4yn 1770185
# /m/02w5q6 2629676
# /m/01kgxf 686844
# /m/02q7yfq 254488
# /m/05bpg3 2551972
# /m/02hzz 2157287
# /m/01ry0f 2618466
# /m/025t9b 885063
# /m/029k55 700575
# /m/054lpb6 2046396
# /m/016z68 2540765
# /m/022yb4 2668271
# /m/0175wg 1219737
# /m/023n39 2914091
# /m/031ydm 51030
# /m/03_vx9 2936539
# /m/02zhkz 2821301
# /m/05sns6 1598899
# /m/012_53 2801018
# /m/044mrh 72023
# /m/01fyzy 2739570
# /m/032zg9 1562512
# /m/01kwld 35794
# /m/02ts3h 2801020
# /m/06v8s0 2821302
# /m/01mt1fy 700576
# /m/07mz77 2175199
# /m/044n3h 118874
# /m/0gtv7pk 149234
# /m/07f3xb 134300
# /m/03_wtr 8645
# /m/0401sg 16614
# /m/044mm6 22447
# /m/05b4l5x 102012
# 0

# %%
model.rank

# %%
len(triples)
# Out:
# 20466

# %%
po_query_pairs('/m/027rn', entities)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-53-d54730106684> in <module>()
# ----> 1 po_query_pairs('/m/027rn', entities)
#
# <ipython-input-52-1d70c4fc9373> in po_query_pairs(obj, entities)
#      35
#      36 def po_query_pairs(obj, entities):
# ---> 37     return [ pair_id(subj, obj) for subj in entities if pair_id(subj, obj) > -1]
#      38
#      39 def pair_id(subj, obj):
#
# <ipython-input-52-1d70c4fc9373> in pair_id(subj, obj)
#      38
#      39 def pair_id(subj, obj):
# ---> 40     pair = entity_pairs[(entity_pairs['subj'] == subj) & (entity_pairs['obj'] == obj)]
#      41     if len(pair) > 0:
#      42         return pair['pid'].values[0]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     761                 other = np.asarray(other)
#     762
# --> 763             res = na_op(values, other)
#     764             if isscalar(res):
#     765                 raise TypeError('Could not compare %s type with Series' %
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in na_op(x, y)
#     681                     result = lib.vec_compare(x, y, op)
#     682             else:
# --> 683                 result = lib.scalar_compare(x, y, op)
#     684         else:
#     685
#
# KeyboardInterrupt:

# %%
triples['sp_reciprocal_rank'] = sp_query_reciprocal_rank(model, triples['subj'], triples['rid'], triples['obj'], entities)
triples['po_reciprocal_rank'] = po_query_reciprocal_rank(model, triples['subj'], triples['rid'], triples['obj'], entities)
triples['sp_hits_at_10'] = sp_query_hits_at_10(model, triples['subj'], triples['rid'], triples['obj'], entities)
triples['po_hits_at_10'] = po_query_hits_at_10(model, triples['subj'], triples['rid'], triples['obj'], entities)

mrr = (triples['sp_reciprocal_rank'].sum() + triples['po_reciprocal_rank'].sum()) / (np.float(len(triples)) * 2.0)
hits_at_10 = (triples['sp_hits_at_10'].sum() + triples['po_hits_at_10'].sum()) / (np.float(len(triples)) * 2.0)

print 'Mean reciprocal rank:', mrr
print 'HITS@10:', hits_at_10
# Out:
# 0          /m/08966
# 1         /m/01hww_
# 2        /m/09v3jyg
# 3          /m/02jx1
# 4          /m/02jx1
# 5         /m/02bfmn
# 6        /m/05zrvfd
# 7          /m/060bp
# 8         /m/07l450
# 9         /m/07h1h5
# 10       /m/0djb3vw
# 11         /m/031y2
# 12         /m/01d8l
# 13         /m/0ydpd
# 14        /m/0738b8
# 15         /m/070xg
# 16         /m/0mwk9
# 17        /m/09306z
# 18         /m/0kbws
# 19         /m/0kbws
# 20        /m/017j69
# 21         /m/07z1m
# 22       /m/03gqgt3
# 23        /m/01c9f2
# 24        /m/01c9f2
# 25         /m/01lp8
# 26        /m/01xwqn
# 27       /m/065ym0c
# 28        /m/06kxk2
# 29        /m/08q1tg
#             ...
# 20436    /m/043sct5
# 20437      /m/0c921
# 20438      /m/0d085
# 20439     /m/05mt_q
# 20440     /m/02hct1
# 20441     /m/084qpk
# 20442      /m/085h1
# 20443      /m/0glnm
# 20444       /m/0mkg
# 20445      /m/0gthm
# 20446    /m/0gvvf4j
# 20447      /m/0b3wk
# 20448      /m/0l15n
# 20449      /m/0_565
# 20450    /m/02ppm4q
# 20451     /m/03q3sy
# 20452    /m/0gl02yg
# 20453      /m/0fkvn
# 20454    /m/05q8pss
# 20455      /m/0c9c0
# 20456      /m/0fx2s
# 20457      /m/01w5m
# 20458    /m/03cmsqb
# 20459      /m/04yt7
# 20460     /m/02lk60
# 20461      /m/0l5yl
# 20462     /m/01z5tr
# 20463      /m/0p5mw
# 20464      /m/0727h
# 20465     /m/050r1z
# Name: subj, dtype: object /m/0dclg
# ValueErrorTraceback (most recent call last)
# <ipython-input-36-be26a88e3088> in <module>()
# ----> 1 triples['sp_reciprocal_rank'] = sp_query_reciprocal_rank(model, triples['subj'], triples['rid'], triples['obj'], entities)
#       2 triples['po_reciprocal_rank'] = po_query_reciprocal_rank(model, triples['subj'], triples['rid'], triples['obj'], entities)
#       3 triples['sp_hits_at_10'] = sp_query_hits_at_10(model, triples['subj'], triples['rid'], triples['obj'], entities)
#       4 triples['po_hits_at_10'] = po_query_hits_at_10(model, triples['subj'], triples['rid'], triples['obj'], entities)
#       5
#
# <ipython-input-33-c7c1a4ef0af5> in sp_query_reciprocal_rank(model, subj, rid, obj, entities)
#       1 def sp_query_reciprocal_rank(model, subj, rid, obj, entities):
# ----> 2     objs = [ result[0] for result in sp_query_results(model, subj, rid, entities) ]
#       3     return reciprocal_rank(obj, objs)
#       4
#       5 def sp_query_hits_at_10(model, subj, rid, obj, entities):
#
# <ipython-input-33-c7c1a4ef0af5> in sp_query_results(model, subj, rid, entities)
#      11
#      12 def sp_query_results(model, subj, rid, entities):
# ---> 13     return sorted([ [ subj, model.rank(pid, rid) ] for pid in sp_query_pairs(subj, entities) ],
#      14                   reverse=True,
#      15                   key=itemgetter(1))
#
# <ipython-input-33-c7c1a4ef0af5> in sp_query_pairs(subj, entities)
#      16
#      17 def sp_query_pairs(subj, entities):
# ---> 18     return [ pair_id(subj, obj) for obj in entities ]
#      19
#      20 def po_query_reciprocal_rank(model, subj, rid, obj, entities):
#
# <ipython-input-33-c7c1a4ef0af5> in pair_id(subj, obj)
#      39 def pair_id(subj, obj):
#      40     print subj, obj
# ---> 41     pair = entity_pairs[(entity_pairs['subj'] == subj) & (entity_pairs['obj'] == obj)]
#      42     return pair['pid'].values[0]
#      43
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     733             name = _maybe_match_name(self, other)
#     734             if len(self) != len(other):
# --> 735                 raise ValueError('Series lengths must match to compare')
#     736             return self._constructor(na_op(self.values, other.values),
#     737                                      index=self.index, name=name)
#
# ValueError: Series lengths must match to compare

# %% [markdown]
# ## References
#
# [[1]](https://www.microsoft.com/en-us/download/details.aspx?id=52312) K. Toutanova, "FB215-237 Knowledge Base Completion Dataset," Web page https://www.microsoft.com/en-us/download/details.aspx?id=52312, May 2016. Last accessed 2016-08-14.
#
# [[2]](https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/main_cvsc2015.pdf) K. Toutanova and D. Chen, “Observed versus latent features for knowledge base and text inference,” in 3rd Workshop on Continuous Vector Space Models and Their Compositionality, Jul. 2015.
